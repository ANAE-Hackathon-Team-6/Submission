# %%
import numpy as np
from os import path
import pickle

# %%
import pandas as pd 
suggestions = pd.read_csv('/kaggle/input/activities/activity.csv')
real_activities = pd.read_csv('/kaggle/input/real-with-def/activities_with_definitions (2).csv')
real_activities
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       code_activity                      name_activity  description  \
# 0             72232                      Typographiste          NaN
# 1             72231                         Typographe          NaN
# 2             72230                        Scannériste          NaN
# 3             72229               Retoucheur-chromiste          NaN
# ...

# %%
suggestions
# Out:
#        code_pro       wilaya                            field  \
# 0      P6B3R8CC      Algiers                              NaN
# 1      LPC2SE3W      Algiers           Services à la personne
# 2      DBX8Y5D7        Batna  Conseil, Expertise et formation
# 3      PYC53DLT        Msila           Services à la personne
# 4      TLLSNCC9      Algiers           Services à la personne
# ...         ...          ...                              ...
# 14957  91BRUZKY  Constantine           Services à la personne
# 14958  LCKR2STV      Algiers  Conseil, Expertise et formation
# 14959  MBQNVBK2       Bouira  Conseil, Expertise et formation
# 14960  BEB2S8T8       Bouira         Services aux entreprises
# 14961  Y278MG22      Algiers         Services aux entreprises
#
#                                                 activity  \
# 0      Technicien de Maintenance du matériel Prépress...
# 1                    معالجة ملفات تأشيرة و خدمات الزبائن
# ...

# %%
subset = suggestions[:100]
subset
# Out:
#     code_pro       wilaya                            field  \
# 0   P6B3R8CC      Algiers                              NaN
# 1   LPC2SE3W      Algiers           Services à la personne
# 2   DBX8Y5D7        Batna  Conseil, Expertise et formation
# 3   PYC53DLT        Msila           Services à la personne
# 4   TLLSNCC9      Algiers           Services à la personne
# ..       ...          ...                              ...
# 95  Z9LQXTQF      Mascara           Prestations à domicile
# 96  TMXRVPVV    Aïn Defla           Services à la personne
# 97  44XG652K   Mostaganem           Prestations à domicile
# 98  6E1WXF7P  Constantine         Services aux entreprises
# 99  ZDLGVB4Q      Algiers           Services à la personne
#
#                                              activity  \
# 0   Technicien de Maintenance du matériel Prépress...
# 1                 معالجة ملفات تأشيرة و خدمات الزبائن
# 2           مستشار مختص بتأشيرات السفر و برامج الهجرة
# ...

# %%
import mtranslate.core as mt
import pandas as pd
from langdetect import detect

activity_column = "activity"  # Column name for activities
description_column = "description"  # Column name for descriptions
translated_column_name = "combined_translation"  # New column name

# Function to translate text
def translate_text(text):
    try:
        if detect(str(text)) == "fr":
            return text  # Keep original if already in French
        return mt.translate(str(text), 'fr')
    except Exception:
        return None  # Mark failed translations as None

# Function to translate and combine DataFrame columns
def translate_and_combine(df, activity_column, description_column):
    translated_texts = []
    
    for activity, description in zip(df[activity_column], df[description_column]):
        translated_activity = translate_text(activity)
        translated_description = translate_text(description)
        
        # Combine both translations
        combined_translation = f"{translated_activity} - {translated_description}"
        translated_texts.append(combined_translation)
    
    df[translated_column_name] = translated_texts
    print("Translation complete. New column added to DataFrame.")
    return df

# Example usage:
df = translate_and_combine(subset, activity_column, description_column)
df.to_csv("translated_file.csv", index=False)  # Save the updated DataFrame
# Out:
# Translation complete. New column added to DataFrame.
# <ipython-input-16-3db866f5af33>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[translated_column_name] = translated_texts

# %%
# !pip install langchain langchain-community

# %%
# !pip install pinecone
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.4/421.4 kB 6.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# data_list = real_activities['name_activity'].tolist()
# data = data_list[0:95]

# %%
# Initialize Pinecone
from pinecone import Pinecone, ServerlessSpec
pc = Pinecone(api_key="pcsk_34KbSm_2WQhegrRfgD8uQjoUw8VNgjXhfgWxqA7KLMGZaqNjCB5XiDvjrdMkgasYhrWtZD")

# Specify the index name (replace with your actual index name)
index_name = "final-index-desc"

# %%
if not index_name in pc.list_indexes().names():
    index = pc.create_index(
        name=index_name,
        dimension=1024,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        ) 
    )
else:
    index = pc.Index(index_name)

# %%
from pinecone import Pinecone


# Connect to the index
index = pc.Index(index_name)  # Connect to the existing index

# Convert column to list
# Convert column to list, ensuring all values are strings and handling NaNs
data_list = (
    real_activities['name_activity'].astype(str) + " " + real_activities['definition'].astype(str)
).tolist()


# Process in batches of 96
batch_size = 96

for i in range(0, len(data_list), batch_size):
    batch_data = data_list[i:i + batch_size]  # Get batch of 96 items
    
    # Embed the batch
    embeddings = pc.inference.embed(
        model="llama-text-embed-v2",
        inputs=batch_data,
        parameters={"input_type": "passage"}
    )

    # Prepare vectors with unique IDs
    vectors = []
    for idx, (text, embedding) in enumerate(zip(batch_data, embeddings), start=i):
        vectors.append({
            "id": str(idx),  # Unique string ID
            "values": embedding['values'],  # Extract embedding values
            "metadata": {'text': text}  # Store original text
        })

    # Upsert batch into Pinecone index
    index.upsert(vectors=vectors, namespace="ns1")
    
    print(f"Inserted batch {i//batch_size + 1} into Pinecone")

print("All data successfully inserted into Pinecone!")
# Out:
# Inserted batch 1 into Pinecone
# Inserted batch 2 into Pinecone
# Inserted batch 3 into Pinecone
# Inserted batch 4 into Pinecone
# Inserted batch 5 into Pinecone
# Inserted batch 6 into Pinecone
# Inserted batch 7 into Pinecone
# Inserted batch 8 into Pinecone
# Inserted batch 9 into Pinecone
# Inserted batch 10 into Pinecone
# Inserted batch 11 into Pinecone
# Inserted batch 12 into Pinecone
# Inserted batch 13 into Pinecone
# Inserted batch 14 into Pinecone
# Inserted batch 15 into Pinecone
# All data successfully inserted into Pinecone!

# %%
# template = """
# You are an AI assistant designed to optimize the evaluation of activity suggestions for auto-entrepreneurs in Algeria. 

# - Identify and remove duplicate suggestions.
# similar activity if it exists: {0}
# User activity suggestion: {1}.

# say if there is a redundancy or not. with the similar one if it exist.

# """

# %%
api_key='pcsk_34KbSm_2WQhegrRfgD8uQjoUw8VNgjXhfgWxqA7KLMGZaqNjCB5XiDvjrdMkgasYhrWtZD'

# %%
query = "electricien specialisé en électroménager"

x = pc.inference.embed(
    model="llama-text-embed-v2",
    inputs=[query],
    parameters={
        "input_type": "query"
    }
)

results = index.query(
    namespace="ns1",
    vector=x[0].values,
    top_k=5,
    include_values=False,
    include_metadata=True
)

print(results)
# Out:
# {'matches': [{'id': '478',
#               'metadata': {'text': "Étlectromécanicien L'électromécanicien est "
#                                    "un professionnel chargé de l'installation, "
#                                    'de la maintenance et de la réparation '
#                                    "d'équipements électromécaniques, tels que "
#                                    'les moteurs électriques, les systèmes '
#                                    "d'automatisation et les appareils "
#                                    'électroménagers.'},
#               'score': 0.532381475,
#               'values': []},
#              {'id': '848',
#               'metadata': {'text': 'Technicien en électroménager Technicien '
#                                    "chargé de la réparation et de l'entretien "
#                                    'des appareils électroménagers '
#                                    '(réfrigérateurs, lave-linge, fours, etc.), '
# ...

# %%
import pandas as pd
# Initialize Pinecone
from pinecone import Pinecone, ServerlessSpec
pc = Pinecone(api_key="pcsk_34KbSm_2WQhegrRfgD8uQjoUw8VNgjXhfgWxqA7KLMGZaqNjCB5XiDvjrdMkgasYhrWtZD")
real_activities = pd.read_csv("/kaggle/input/real-with-def/activities_with_definitions (2).csv")

# Placeholder logic: Randomly reject half the time (you can replace this logic)
def get_relevant(query, top_k=10, threshold=0.4, real_activities=None):
    index_name = "final-index-desc"  
    if not index_name in pc.list_indexes().names():
        index = pc.create_index(
            name=index_name,
            dimension=1024,
            metric="cosine",
            spec=ServerlessSpec(
                cloud="aws",
                region="us-east-1"
            ) 
        )
    else:
        index = pc.Index(index_name)

    # Generate embedding for the query
    query_embedding = pc.inference.embed(
        model="llama-text-embed-v2",
        inputs=[query],
        parameters={"input_type": "query"}
    )

    # Perform Pinecone query
    res = index.query(
        namespace="ns1",
        vector=query_embedding[0].values,  # Use the correct embedding format
        top_k=top_k,
        include_values=False,
        include_metadata=True
    )

    # Extract matches
    matches = res.get("matches", [])

    # Filter relevant results based on threshold
    filtered_matches = [match for match in matches if match["score"] >= threshold]

    # Prepare redundant activity IDs
    redundant_activities = [int(match["id"]) for match in filtered_matches]

    # Retrieve all similar activities using .loc[] and checking for valid indices
    most_similar = (
        real_activities.loc[redundant_activities, "name_activity"].tolist()
        # if redundant_activities and real_activities is not None
        # else ["No similar activity found"]
    )

    # Determine if there's redundancy
    is_redundant = len(redundant_activities) > 0

    return is_redundant, most_similar, redundant_activities

# %%
get_relevant("electricien specialisé en électroménager", top_k=5,real_activities=real_activities)
# Out:
# (True,
#  ['Étlectromécanicien',
#   'Technicien en électroménager',
#   'Réparateur en électroménager',
#   "Electromécanicien d'entretien d'installations électriques",
#   'Électromécanicien de régulation'],
#  [478, 848, 854, 356, 669])

# %%
get_relevant("electricien specialisé en électroménager", top_k=5,real_activities=real_activities)
# Out:
# (True,
#  ['Étlectromécanicien',
#   'Technicien en électroménager',
#   'Réparateur en électroménager',
#   "Electromécanicien d'entretien d'installations électriques",
#   'Électromécanicien de régulation'],
#  [478, 848, 854, 356, 669])

# %%
real_activities.iloc[]['name_activity']
# Out:
# 'Électromécanicien de régulation'

# %% [markdown]
# # chatbot

# %%
import google.generativeai as genai
genai_key='AIzaSyAAH27cavT1ruEbeFWDpNXMfqazy41m4F0'
genai.configure(api_key=genai_key)

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
template =
"""
Vous êtes un assistant IA conçu pour optimiser l’évaluation des suggestions d’activités pour les auto-entrepreneurs en Algérie.  

- Identifiez et supprimez les suggestions en double.  
Activité similaire si elle existe : {0}  
Suggestion d’activité de l’utilisateur : {1}.  

Indiquez s'il y a une redondance ou non, avec les activities similaires si elles existent.  
"""

# %%
# !pip install mtranslate
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3673 sha256=b1ab5d0e8ca66ad04f057e062b30b92095fccc58c520620c59399ea83f80476b
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# ...

# %%
# !pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 12.2 MB/s eta 0:00:0000:010:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=76c15c1c2e1c0af92e6a1ae2438c6de54a93e87245152f5cc87acad9d24a4da3
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from langdetect import detect
from mtranslate import translate

def get_answer(query, model=None, top_k=5, template="", real_activities=None):
    # Detect language and translate to French if needed
    detected_lang = detect(query)
    if detected_lang != "fr":
        query = translate(query, "fr")

    # Retrieve relevant content
    is_redundant, most_similar, redundant_activities = get_relevant(query, top_k, real_activities=real_activities)

    if not is_redundant:
        return "Il n'y a pas de redondance."

    # Format input text
    input_text = template.format("\n".join(most_similar), query)
    
    # Generate answer using the model
    ans = model.generate_content(input_text)
    
    return ans.text

# %%
get_answer("an ai developer",model=model, top_k=4,template=template ,real_activities=real_activities)
# Out:
# '**Suggestion de l\'utilisateur :** Développeur d\'IA\n\n**Activités similaires existantes :**\n\n* Développeur(se) de systèmes d\'intelligence artificielle\n* Analyste développeur\n* Développeur(se) cloud\n* Développeur(se) logiciel\n\n**Conclusion :**\n\nIl y a une redondance avec les activités similaires existantes. "Développeur d\'IA" est couvert par "Développeur(se) de systèmes d\'intelligence artificielle".'

# %%
# load_dotenv()
# api_key = environ.get("PC_KEY")
# genai_key = environ.get("GENAI_KEY")

# %%
import pandas as pd
from pinecone import Pinecone, ServerlessSpec
import google.generativeai as genai
from langdetect import detect
from mtranslate import translate

class ConversationalAI:
    def __init__(self, pinecone_api_key, gemini_api_key, index_name="final-index-desc", real_activities_path="activities_with_definitions.csv"):
        # Initialize Pinecone
        self.pc = Pinecone(api_key=pinecone_api_key)
        self.index_name = index_name
        self.real_activities = pd.read_csv(real_activities_path)

        # Initialize Pinecone index
        if self.index_name not in self.pc.list_indexes().names():
            self.pc.create_index(
                name=self.index_name,
                dimension=1024,
                metric="cosine",
                spec=ServerlessSpec(cloud="aws", region="us-east-1")
            )
        self.index = self.pc.Index(self.index_name)

        # Initialize Google Gemini AI
        genai.configure(api_key=gemini_api_key)
        self.model = genai.GenerativeModel('gemini-pro')

        # Define response template
        self.template = """
        Vous êtes un assistant IA conçu pour optimiser l’évaluation des suggestions d’activités pour les auto-entrepreneurs en Algérie.  

        - Identifiez et supprimez les suggestions en double.  
        Activités similaires si elles existent : {0}  
        Suggestion d’activité de l’utilisateur : {1}.  

        Indiquez s'il y a une redondance ou non, avec les activités similaires si elles existent.  
        """

        # Initialize conversation history
        self.history = []
    
    def extract_activity(self, query):
        """Extracts the activity from the user's query using Gemini AI."""
        prompt = f"""
        Extract the main business activity mentioned in the following user query:
        "{query}"
        Provide only the extracted activity and nothing else dont give acronyms
        """
        response = self.model.generate_content(prompt)
        return response.text.strip()

    def get_relevant(self, query, top_k=10, threshold=0.4):
        """Retrieves the most relevant activities based on the extracted activity."""
        query_embedding = self.pc.inference.embed(
            model="llama-text-embed-v2",
            inputs=[query],
            parameters={"input_type": "query"}
        )

        res = self.index.query(
            namespace="ns1",
            vector=query_embedding[0].values,
            top_k=top_k,
            include_values=False,
            include_metadata=True
        )

        matches = res.get("matches", [])
        filtered_matches = [match for match in matches if match["score"] >= threshold]
        redundant_activities = [int(match["id"]) for match in filtered_matches]

        most_similar = (
            self.real_activities.loc[redundant_activities, "name_activity"].tolist()
            if redundant_activities and self.real_activities is not None
            else ["Aucune activité similaire trouvée."]
        )

        return len(redundant_activities) > 0, most_similar, redundant_activities

    def get_answer(self, query, top_k=5):
        """Extracts the activity, checks redundancy, and generates a response."""
        detected_lang = detect(query)
        if detected_lang != "fr":
            query = translate(query, "fr")

        extracted_activity = self.extract_activity(query)  
        print('the extracted activity is :',extracted_activity)
        if not extracted_activity:
            return "Je n'ai pas pu identifier une activité spécifique. Pouvez-vous reformuler votre question ?"

        is_redundant, most_similar, _ = self.get_relevant(extracted_activity, top_k)
        if not is_redundant:
            return "Il n'y a pas de redondance."

        context = "\n".join(self.history[-10:])
        input_text = f"{context}\n\n" + self.template.format("\n".join(most_similar), extracted_activity)
        ans = self.model.generate_content(input_text)

        self.history.append(f"Utilisateur: {query}")
        self.history.append(f"Chatbot: {ans.text}")

        return ans.text

    def conversational_ai(self, query):
        """Processes user queries and returns a response."""
        return self.get_answer(query)

# Example usage
if __name__ == "__main__":
    pinecone_api_key = "pcsk_34KbSm_2WQhegrRfgD8uQjoUw8VNgjXhfgWxqA7KLMGZaqNjCB5XiDvjrdMkgasYhrWtZD"
    gemini_api_key = "AIzaSyAAH27cavT1ruEbeFWDpNXMfqazy41m4F0"
    real_activities_path = "/kaggle/input/real-with-def/activities_with_definitions (2).csv"

    chatbot = ConversationalAI(pinecone_api_key, gemini_api_key, real_activities_path=real_activities_path)

    while True:
        user_input = input("Vous: ")
        if user_input.lower() in ["exit", "quit", "stop"]:
            print("Chatbot: Au revoir !")
            break

        response = chatbot.conversational_ai(user_input)
        print(f"Chatbot: {response}")
# Out:
# Vous:  i want to become an ai developper
# the extracted activity is : Artificial Intelligence Development
# Chatbot: **Activité similaire identifiée :**
#
# * Développeur(se) de systèmes d'intelligence artificielle
#
# **Donc, l'activité dupliquée est :**
#
# * Artificial Intelligence Development
#
# **Il y a donc une redondance dans les suggestions d'activités.**
# Vous:  exit
# Chatbot: Au revoir !

# %%
import pandas as pd
from pinecone import Pinecone, ServerlessSpec
import google.generativeai as genai
from langdetect import detect
from mtranslate import translate

class SearchAI:
    def __init__(self, pinecone_api_key, gemini_api_key, index_name="final-index-desc", real_activities_path="activities_with_definitions.csv"):
        # Initialize Pinecone
        self.pc = Pinecone(api_key=pinecone_api_key)
        self.index_name = index_name
        self.real_activities = pd.read_csv(real_activities_path)

        # Initialize Pinecone index
        if self.index_name not in self.pc.list_indexes().names():
            self.pc.create_index(
                name=self.index_name,
                dimension=1024,
                metric="cosine",
                spec=ServerlessSpec(cloud="aws", region="us-east-1")
            )
        self.index = self.pc.Index(self.index_name)

        # Initialize Google Gemini AI for activity extraction
        genai.configure(api_key=gemini_api_key)
        self.model = genai.GenerativeModel('gemini-pro')
    
    def extract_activity(self, query):
        """Extracts the activity from the user's query using Gemini AI."""
        prompt = f"""
        Extract the main business activity mentioned in the following user query:
        "{query}"
        Provide only the extracted activity and nothing else. dont use acronyms
        """
        response = self.model.generate_content(prompt)
        return response.text.strip()

    def get_relevant(self, query, top_k=10, threshold=0.4):
        """Retrieves the most relevant activities based on the extracted activity."""
        query_embedding = self.pc.inference.embed(
            model="llama-text-embed-v2",
            inputs=[query],
            parameters={"input_type": "query"}
        )

        res = self.index.query(
            namespace="ns1",
            vector=query_embedding[0].values,
            top_k=top_k,
            include_values=False,
            include_metadata=True
        )

        matches = res.get("matches", [])
        filtered_matches = [match for match in matches if match["score"] >= threshold]
        redundant_activities = [int(match["id"]) for match in filtered_matches]

        most_similar = (
            self.real_activities.loc[redundant_activities, "name_activity"].tolist()
            if redundant_activities and self.real_activities is not None
            else ["Aucune activité similaire trouvée."]
        )

        return most_similar

    def search_activity(self, query, top_k=5):
        """Extracts the activity and retrieves similar activities without generating a response."""
        extracted_activity = self.extract_activity(query)
        detected_lang = detect(extracted_activity)
        if detected_lang != "fr":
            extracted_activity = translate(extracted_activity, "fr")

        if not extracted_activity:
            return "Je n'ai pas pu identifier une activité spécifique. Pouvez-vous reformuler votre question ?"
        
        similar_activities = self.get_relevant(extracted_activity, top_k,threshold=0.3)
        return similar_activities

# %%
    pinecone_api_key = "pcsk_34KbSm_2WQhegrRfgD8uQjoUw8VNgjXhfgWxqA7KLMGZaqNjCB5XiDvjrdMkgasYhrWtZD"
    gemini_api_key = "AIzaSyAAH27cavT1ruEbeFWDpNXMfqazy41m4F0"
    real_activities_path = "/kaggle/input/real-with-def/activities_with_definitions (2).csv"

    searchbot = SearchAI(pinecone_api_key, gemini_api_key, real_activities_path=real_activities_path)

# %%
searchbot.search_activity("developper IA")
# Out:
# ["Développeur(se) de systèmes d'intelligence artificielle",
#  'Chercheur(euse) en intelligence artificielle',
#  'Ingénieur(e) en intelligence artificielle',
#  'Ingénieur(e) en apprentissage automatique',
#  'Architecte de solutions en intelligence artificielle']
